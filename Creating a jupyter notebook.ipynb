# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# __KETAN MOHAN JANAI__

# %% [markdown]
# Intern at Cognizant

# %% [markdown]
# <i>Data is the new cool its amazing how data influences the decision made by a company and I love to be the one who knows how to make right decision by analyzing and making right predictions<i/>

# %% [markdown]
# ### The following code prints the sum of n prime numbers

# %%
a = int(input())
b = int(input())
print("Addition of above numbers is ",a + b )
# Out:
# 1
# 2
# Addition of above numbers is  3

# %% [markdown]
# <ul>
# <li>Morning</li>
# <li>Afternoon</li>
# <li>Evening</li>
# <li>Night</li>
# </ul>
#
# <a> href="https://www.google.com" >Link to Google</a>
#
# ![depositphotos_140595044-stock-illustration-monkey-soldier-with-a-cigarette.jpg](attachment:depositphotos_140595044-stock-illustration-monkey-soldier-with-a-cigarette.jpg)
